# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    mass_npea  size_npear  malign_ratio  damage_size  exposed_area  \
# 0    6930.90     2919.02       0.42116      51.8298    988829.407
# 1   15635.70     4879.36       0.31206     223.5500   2058426.301
# 2   10376.20     2613.88       0.25191     127.3370   1434676.100
# 3   13093.80     4510.06       0.34444     155.4400   1812195.183
# 4    7545.21     2882.36       0.38201      85.1237   1043917.501
#
#    std_dev_malign  err_malign  malign_penalty  damage_ratio  tumor_size
# 0         109.487     2758.76              72       39.3620      14.103
# 1         248.881     5952.53             240       22.0253       2.648
# 2         160.093     4635.26              73       29.9963       1.688
# 3         173.015     5273.87              32       28.1354       3.796
# 4         124.414     3263.35              57       35.0200      18.023

# %%
import matplotlib as plt
# %matplotlib inline

# %%
plt.pyplot.scatter(df.mass_npea,df.tumor_size)

# %%
df.mass_npea.corr(df.size_npear)
# Out:
# 0.9073351614502658

# %%
df.shape
# Out:
# (9146, 10)

# %%
df.corr(method='spearman')
# Out:
#                 mass_npea  size_npear  malign_ratio  damage_size  \
# mass_npea        1.000000    0.892810      0.133690     0.936968
# size_npear       0.892810    1.000000      0.537995     0.806091
# malign_ratio     0.133690    0.537995      1.000000     0.051301
# damage_size      0.936968    0.806091      0.051301     1.000000
# exposed_area     0.997746    0.888266      0.128533     0.932776
# std_dev_malign   0.963797    0.912545      0.230716     0.931758
# err_malign       0.917341    0.813492      0.111839     0.865729
# malign_penalty   0.598827    0.578232      0.151674     0.596413
# damage_ratio    -0.921421   -0.798627     -0.071514    -0.908593
# tumor_size      -0.002609    0.168228      0.388632    -0.143517
#
#                 exposed_area  std_dev_malign  err_malign  malign_penalty  \
# mass_npea           0.997746        0.963797    0.917341        0.598827
# size_npear          0.888266        0.912545    0.813492        0.578232
# ...

# %%
df1=df.drop(['exposed_area'],axis=1)

# %%
df1.columns
# Out:
# Index(['mass_npea', 'size_npear', 'malign_ratio', 'damage_size',
#        'std_dev_malign', 'err_malign', 'malign_penalty', 'damage_ratio',
#        'tumor_size'],
#       dtype='object')

# %%
dft=pd.read_csv('Test.csv')
dft.head()
# Out:
#    mass_npea  size_npear  malign_ratio  damage_size  exposed_area  \
# 0    4946.44      914.06       0.18479      54.5566  6.628345e+05
# 1    5613.85     1629.12       0.29019      51.5524  7.842271e+05
# 2   12421.10     3062.41       0.24654     154.1560  1.763575e+06
# 3    6830.77     2457.66       0.35979      56.8995  9.296623e+05
# 4   33407.80    12353.60       0.36978     219.0740  4.595871e+06
#
#    std_dev_malign  err_malign  malign_penalty  damage_ratio
# 0         67.0525     2301.76              22       41.9554
# 1         80.1986     3235.00              48       40.7410
# 2        186.8590     4684.63              63       29.4778
# 3         92.7361     3211.93              42       38.5027
# 4        493.3370    13389.36             187       26.8449

# %%
dft.corr(method='spearman')
# Out:
#                 mass_npea  size_npear  malign_ratio  damage_size  \
# mass_npea        1.000000    0.893195      0.131417     0.937660
# size_npear       0.893195    1.000000      0.535279     0.807243
# malign_ratio     0.131417    0.535279      1.000000     0.049787
# damage_size      0.937660    0.807243      0.049787     1.000000
# exposed_area     0.997836    0.889368      0.127730     0.933440
# std_dev_malign   0.964578    0.911154      0.225732     0.933060
# err_malign       0.920475    0.817123      0.111184     0.872035
# malign_penalty   0.596012    0.572989      0.142178     0.592831
# damage_ratio    -0.919152   -0.799703     -0.070364    -0.909064
#
#                 exposed_area  std_dev_malign  err_malign  malign_penalty  \
# mass_npea           0.997836        0.964578    0.920475        0.596012
# size_npear          0.889368        0.911154    0.817123        0.572989
# malign_ratio        0.127730        0.225732    0.111184        0.142178
# ...

# %%
dft2=dft.drop(['exposed_area'],axis=1)
dft2.columns
# Out:
# Index(['mass_npea', 'size_npear', 'malign_ratio', 'damage_size',
#        'std_dev_malign', 'err_malign', 'malign_penalty', 'damage_ratio'],
#       dtype='object')

# %%
X_train=df1.drop(['tumor_size'],axis=1)

# %%
X_train.head()
# Out:
#    mass_npea  size_npear  malign_ratio  damage_size  std_dev_malign  \
# 0    6930.90     2919.02       0.42116      51.8298         109.487
# 1   15635.70     4879.36       0.31206     223.5500         248.881
# 2   10376.20     2613.88       0.25191     127.3370         160.093
# 3   13093.80     4510.06       0.34444     155.4400         173.015
# 4    7545.21     2882.36       0.38201      85.1237         124.414
#
#    err_malign  malign_penalty  damage_ratio
# 0     2758.76              72       39.3620
# 1     5952.53             240       22.0253
# 2     4635.26              73       29.9963
# 3     5273.87              32       28.1354
# 4     3263.35              57       35.0200

# %%
Y_train=df1.tumor_size

# %%
Y_train
# Out:
# 0       14.103
# 1        2.648
# 2        1.688
# 3        3.796
# 4       18.023
#          ...
# 9141    13.127
# 9142    17.091
# 9143     1.971
# 9144    17.749
# 9145    14.103
# Name: tumor_size, Length: 9146, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
Lreg=LinearRegression()

# %%
Lreg.fit(X_train,Y_train)
